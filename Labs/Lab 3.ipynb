# %%
import pandas as p
import numpy as np

# %%
index = ['a','b','c','d','e']
series = p.Series(np.arange(5), index=index) #
series
# Out:
# a    0
# b    1
# c    2
# d    3
# e    4
# dtype: int64

# %%
series[['a', 'c']] #how to access?
# Out:
# a    0
# c    2
# dtype: int64

# %%
series[3]
# Out:
# 3

# %%
#Slicing
series['b':'e']
# Out:
# b    1
# c    2
# d    3
# e    4
# dtype: int64

# %%
#filtering the given data
filter = series >=3
series[filter]
# Out:
# d    3
# e    4
# dtype: int64

# %%
s = p.Series(['blue', 'purple', 'red'], index=[0,2,4]) #automatic alignment
s.reindex([2,3,1,0])
# Out:
# 2    purple
# 3       NaN
# 1       NaN
# 0      blue
# dtype: object

# %%
#s.reindex(range(5), fill_value='black')
s.reindex(range(5), method='ffill')
# Out:
# 0      blue
# 1      blue
# 2    purple
# 3    purple
# 4       red
# dtype: object

# %%
index1 = ['a','b','c']
index2 = ['a','b','d','e']
#sdata = {'b':100, 'c':150}
s1 = p.Series([1,2,3],index =index1 )
s2 = p.Series([3,4,5,7], index = index2)

# %%
s1+s2
#s1*2
# Out:
# a    4.0
# b    6.0
# c    NaN
# d    NaN
# e    NaN
# dtype: float64

# %%
#sorting series
#s.sort_values()
s.sort_index()
# Out:
# 0      blue
# 2    purple
# 4       red
# dtype: object

# %%
data = p.DataFrame({ 'children': [4., 6, 3, 3, 2, 3, 5, 4],
                     'pet':      ['cat', 'dog', 'dog', 'fish', 'cat', 'dog', 'cat', 'fish'],
                     'salary':   [90, 24, 44, 27, 32, 59, 36, 27]})

# %%
data
# Out:
#    children   pet  salary
# 0       4.0   cat      90
# 1       6.0   dog      24
# 2       3.0   dog      44
# 3       3.0  fish      27
# 4       2.0   cat      32
# 5       3.0   dog      59
# 6       5.0   cat      36
# 7       4.0  fish      27

# %%
data.ix[1]
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# children      6
# pet         dog
# salary       24
# Name: 1, dtype: object

# %%
#adding the column is very easy
data['Other Pets']= np.nan

# %%
data.drop(['Other Pets'], axis=1)
# Out:
#    children   pet  salary
# 0       4.0   cat      90
# 1       6.0   dog      24
# 2       3.0   dog      44
# 3       3.0  fish      27
# 4       2.0   cat      32
# 5       3.0   dog      59
# 6       5.0   cat      36
# 7       4.0  fish      27

# %% [markdown]
# **Kaggle Competition Specific**

# %%
import pandas as pd
#read a csv using pandas
df_train = pd.read_csv("train.csv")

# %%
df_train.head(5) #head can be used to see the first few rows of dataframe
# Out:
#    Unnamed: 0 COLLEGE  INCOME  OVERAGE  LEFTOVER   HOUSE  HANDSET_PRICE  \
# 0           0    zero   31953        0         6  313378            161
# 1           1     one   36147        0        13  800586            244
# 2           2     one   27273      230         0  305049            201
# 3           3    zero  120070       38        33  788235            780
# 4           4     one   29215      208        85  224784            241
#
#    OVER_15MINS_CALLS_PER_MONTH  AVERAGE_CALL_DURATION REPORTED_SATISFACTION  \
# 0                            0                      4                 unsat
# 1                            0                      6                 unsat
# 2                           16                     15                 unsat
# 3                            3                      2                 unsat
# 4                           21                      1            very_unsat
#
#   REPORTED_USAGE_LEVEL CONSIDERING_CHANGE_OF_PLAN  LEAVE
# ...

# %%
df_train.shape
# Out:
# (18000, 13)

# %%
#used t#used to remove rows which have nan values, need not be used in our analysis as we dont have any nan values in our dataseto remove rows which have nan values, need not be used in our analysis as we dont have any nan values in our dataset
df_train.dropna(how='any',inplace=True)

# %%
df_train.shape
# Out:
# (18000, 13)

# %%
df_train.COLLEGE  #how to access the column
# Out:
# 0        zero
# 1         one
# 2         one
# 3        zero
# 4         one
# 5        zero
# 6        zero
# 7         one
# 8        zero
# 9        zero
# 10       zero
# 11        one
# 12       zero
# 13        one
# 14        one
# 15       zero
# 16       zero
# 17       zero
# 18       zero
# 19        one
# 20       zero
# 21        one
# 22        one
# 23       zero
# 24        one
# 25        one
# 26        one
# 27       zero
# 28        one
# 29       zero
#          ...
# 17970    zero
# 17971     one
# 17972    zero
# 17973    zero
# 17974    zero
# 17975    zero
# 17976    zero
# 17977    zero
# 17978     one
# 17979    zero
# 17980     one
# 17981     one
# 17982    zero
# 17983     one
# 17984    zero
# 17985    zero
# 17986     one
# 17987     one
# 17988    zero
# 17989    zero
# 17990    zero
# 17991    zero
# 17992     one
# 17993    zero
# 17994     one
# 17995     one
# 17996    zero
# 17997    zero
# 17998    zero
# 17999    zero
# ...

# %%
df_train.COLLEGE.unique() #to know the unique elements in a column of a dataframe
# Out:
# array(['zero', 'one'], dtype=object)

# %%
df_train['COLLEGE'] = df_train['COLLEGE'].replace({"one": "1", "zero": "0"})
 #to replace the elements in a column

# %%
df_train.head(5)
# Out:
#    Unnamed: 0 COLLEGE  INCOME  OVERAGE  LEFTOVER   HOUSE  HANDSET_PRICE  \
# 0           0       0   31953        0         6  313378            161
# 1           1       1   36147        0        13  800586            244
# 2           2       1   27273      230         0  305049            201
# 3           3       0  120070       38        33  788235            780
# 4           4       1   29215      208        85  224784            241
#
#    OVER_15MINS_CALLS_PER_MONTH  AVERAGE_CALL_DURATION REPORTED_SATISFACTION  \
# 0                            0                      4                 unsat
# 1                            0                      6                 unsat
# 2                           16                     15                 unsat
# 3                            3                      2                 unsat
# 4                           21                      1            very_unsat
#
#   REPORTED_USAGE_LEVEL CONSIDERING_CHANGE_OF_PLAN  LEAVE
# ...

# %%
df_train.COLLEGE = df_train.COLLEGE.replace({"1": "one", "0": "zero"}) # wer are just reversing it backto replace the elements in a column

# %%
df_train.head(5)
# Out:
#    Unnamed: 0 COLLEGE  INCOME  OVERAGE  LEFTOVER   HOUSE  HANDSET_PRICE  \
# 0           0    zero   31953        0         6  313378            161
# 1           1     one   36147        0        13  800586            244
# 2           2     one   27273      230         0  305049            201
# 3           3    zero  120070       38        33  788235            780
# 4           4     one   29215      208        85  224784            241
#
#    OVER_15MINS_CALLS_PER_MONTH  AVERAGE_CALL_DURATION REPORTED_SATISFACTION  \
# 0                            0                      4                 unsat
# 1                            0                      6                 unsat
# 2                           16                     15                 unsat
# 3                            3                      2                 unsat
# 4                           21                      1            very_unsat
#
#   REPORTED_USAGE_LEVEL CONSIDERING_CHANGE_OF_PLAN  LEAVE
# ...

# %%
df_train.LEAVE.to_csv('train2.csv') #to save a dataframe to csv, here we are saving the LEAVE column in a csv named train2.csv

# %%
#selecting features
features = list(df_train.columns[:11])
print(features)
Y = df_train["LEAVE"]
X = df_train[features]
# Out:
# ['Unnamed: 0', 'COLLEGE', 'INCOME', 'OVERAGE', 'LEFTOVER', 'HOUSE', 'HANDSET_PRICE', 'OVER_15MINS_CALLS_PER_MONTH', 'AVERAGE_CALL_DURATION', 'REPORTED_SATISFACTION', 'REPORTED_USAGE_LEVEL']

# %% [markdown]
# Information gain of different features![image.png](attachment:image.png)

# %%
# we have slightly different features in our dataset, so make your decisions.

# %% [markdown]
# Decision Tree![image.png](attachment:image.png)

# %% [markdown]
# References: Data science for business by By Foster Provost, Tom Fawcett
